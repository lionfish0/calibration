# %%
import numpy as np
from calibration import placeinducingpoints, CalibrationSystem, SparseModel
import gpflow
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %% [markdown]
# ## Simple Scaling Demo
#
# Just two sensors, the low-cost sensor varies between 50% and 150% of the true sensor.
# The latent function models the log scaling of the low-cost sensor.

# %%
X = np.c_[np.linspace(0,20,2001),np.zeros(2001),np.ones(2001)]
if X.shape[1]==3:
    X = np.c_[X[:,0],X[:,0],X[:,1],X[:,2]]
    
y = np.cos(X[:,0])*25+100
Y = np.c_[y,y*(0.5+0.1*X[:,0])].astype(np.float32)
Y = np.log(Y)
refsensor = np.array([1,0])
Z = np.linspace(0,20,5)[:,None]

# %%
plt.plot(X[:,0],Y[:,0])
plt.plot(X[:,0],Y[:,1])

# %%
#modified to consider log(phi1)~=log(phi2) -- the idea
#is that the ratio is important, not the absolute difference...
def transform_fn(samps,Y,sideY):
    return Y*tf.exp(samps[:,:,0:1])
    #return tf.math.log(Y)+samps[:,:,0:1]
    #return tf.exp(Y[None,:,:]+samps[:,:,0:1])
    #           e^y e^f
    #d/dy     = e^y e^f
    #log d/dy = y + f
    
def transform_fn_loggrad(samps,Y,sideY):
    return samps[:,:,0:1]
    #return -tf.math.log(Y)[None,:,:] #Had to reshape this as the samps don't have any effect
    #return samps[:,:,0:1]-tf.math.log(Y)
    #return Y[None,:,:]+samps[:,:,0:1]

k = gpflow.kernels.RBF(1,15)+gpflow.kernels.Bias(1)
kernelindices = [[0]*len(refsensor)]*1
cs = CalibrationSystem(X, Y, Z, refsensor, 1, transform_fn, transform_fn_loggrad, [k],kernelindices,likelihoodstd=0.01,lr=0.05,minibatchsize=20)
import time
st = time.time()
elbo_record = cs.run(its=200,verbose=True)
print(time.time()-st)
# Out:
# Starting Run
# ....................20 (ELBO=13539.5303)
# ....................40 (ELBO=10926.5439)
# ....................60 (ELBO=9566.4443)
# ....................80 (ELBO=9476.5352)
# ....................100 (ELBO=9295.8965)
# ....................120 (ELBO=9310.9121)
# ....................140 (ELBO=9240.4404)
# ....................160 (ELBO=9243.9287)
# ....................180 (ELBO=9316.9551)
# ....................200 (ELBO=9220.2119)
# 22.183220386505127

# %%
plt.plot(np.log(elbo_record),'b-')

# %%
# Out:
# array([0.85644114, 0.8568547 , 0.8572668 , ..., 1.1945192 , 1.194689  ,
#        1.1948595 ], dtype=float32)

# %%
#build test matrix
C = 1
for si,refs in enumerate(refsensor):
    if refs: continue
    x = np.linspace(0,15,151)
    testX = np.zeros([0,3])
    for ci in range(C):
        tempX = np.c_[x,np.ones_like(x)*si,np.full_like(x,ci)]
        testX = np.r_[testX,tempX]#.astype(int)
    testsm = SparseModel(testX,cs.Z,C,cs.k)
    qf_mu,qf_cov = testsm.get_qf(cs.mu,cs.scale)
    samps = testsm.get_samples_one_sensor(cs.mu,cs.scale)

    plt.figure(figsize=[6,4])
    plt.plot(x,1/tf.exp(samps[:,:,0].numpy().T),'b.',alpha=0.0025);
    plt.grid()
    plt.vlines(Z[:,0],.4,.41)
    plt.xlim([0,15])
    #plt.plot([0,15],[0.5+0,0.5+0.1*15],'k-')
    #xs = np.linspace(0,15,100)
    #plt.plot(xs,np.log(xs/10+0.5))
    plt.plot(X[:,0],Y[:,1]/Y[:,0])

# %%
#build test matrix
C = 1
for si,refs in enumerate(refsensor):
    if refs: continue
    x = np.linspace(0,15,151)
    testX = np.zeros([0,3])
    for ci in range(C):
        tempX = np.c_[x,np.ones_like(x)*si,np.full_like(x,ci)]
        testX = np.r_[testX,tempX]#.astype(int)
    testsm = SparseModel(testX,cs.Z,C,cs.k)
    qf_mu,qf_cov = testsm.get_qf(cs.mu,cs.scale)
    samps = testsm.get_samples_one_sensor(cs.mu,cs.scale)
    phi = transform_fn(samps,Y[:,1],None)
    plt.figure(figsize=[6,4])
    #plt.plot(x,1/tf.exp(samps[:,:,0].numpy().T),'b.',alpha=0.0025);
    plt.grid()
    #plt.vlines(Z[:,0],.4,.41)
    #plt.xlim([0,15])
    #plt.plot([0,15],[0.5+0,0.5+0.1*15],'k-')
    #xs = np.linspace(0,15,100)
    #plt.plot(xs,np.log(xs/10+0.5))
    
    #plt.plot(X[:,0],Y[:,1]/Y[:,0])
    plt.plot(X[:,0],np.exp(np.mean(phi.numpy().T,(2))),'k-',alpha=0.1)
    plt.plot(X[:,0],np.exp(Y[:,1]),'b-')

# %% [markdown]
# ## Likelihood Model Demo
#
# Here we have two sensors (reference and a permanently colocated static sensor). We add varying amounts of noise to the 2nd sensor. This is handled by the model.
#
# In this example we use a different transform_fn that arguably isn't as sensible, with a scaling of 1+latent function. This clearly has issues as it allows negative scalings and treats an increase of 1.5x as equivalent in magnitude to a decrease of x0.5. While in reality one would expect 2x and 0.5x to be equivalent.

# %%
N = 501
X = np.linspace(0,260,N)[:,None]
X = np.c_[X,np.zeros(N),np.ones(N)]
Y = np.c_[np.linspace(20,40,N)[:,None],np.linspace(40,80,N)[:,None]]
Y[:,1]*=np.cos(X[:,0]/10)*0.2+1
Y[50:70,1]+=np.random.randn(20)*np.linspace(0,10,20)
Y[70:90,1]+=np.random.randn(20)*np.linspace(10,0,20)
Y[200:250,1]+=np.random.randn(50)*np.linspace(0,30,50)
Y[250:300,1]+=np.random.randn(50)*np.linspace(30,0,50)
Y[:,1]+=np.random.randn(N)*np.linspace(3,0,N)
refsensor = np.array([1,0])
Z = np.linspace(0,260,50)[:,None]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aedf84048c58> in <module>
#       1 N = 501
# ----> 2 X = np.linspace(0,260,N)[:,None]
#       3 X = np.c_[X,np.zeros(N),np.ones(N)]
#       4 Y = np.c_[np.linspace(20,40,N)[:,None],np.linspace(40,80,N)[:,None]]
#       5 Y[:,1]*=np.cos(X[:,0]/10)*0.2+1
#
# NameError: name 'np' is not defined

# %%
def transform_fn(samps,Y,sideY):
    return Y*(1+samps[:,:,0:1])

# %%
k = gpflow.kernels.RBF(100,20)+gpflow.kernels.Bias(100)
kernelindices = [[0]*len(refsensor)]*1

klike = gpflow.kernels.RBF(100,20)+gpflow.kernels.Bias(100)



cs = CalibrationSystem(X, Y, Z, refsensor, 1, transform_fn, [k], kernelindices, likemodel='distribution',gpflowkernellike=klike,likelihoodstd=0.5,minibatchsize=120)
import time
before = time.time()
elbo_record = cs.run(1000)
print(time.time()-before)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-5e80c8d8b7d6> in <module>
#       9 import time
#      10 before = time.time()
# ---> 11 elbo_record = cs.run(1000)
#      12 print(time.time()-before)
#
# ~/Documents/Research/calibration/calibration/__init__.py in run(self, its, samples, threshold, verbose)
#     409         samples: Number of samples for the stochastic sampling of the
#     410         gradient
# --> 411         threshold: if its is None, this is the percentage change between
#     412         the rolling average, over 50 iterations. Default: 0.001 (0.1%).
#     413         """
#
# ~/Documents/Research/calibration/calibration/__init__.py in computeforminibatch(self, justuserefs)
#     359
#     360
# --> 361     def computeforminibatch(self,justuserefs=False):
#     362         if justuserefs: #to start with we just train on data from pairings with reference sensors to help optimisation
#     363             print("!!JUST USING REFERENCE ROWS!!")
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
#build test matrix
C = 1
for si,refs in enumerate(refsensor):
    if refs: continue
    x = np.linspace(0,260,151)
    testX = np.zeros([0,3])
    for ci in range(C):
        tempX = np.c_[x,np.ones_like(x)*si,np.full_like(x,ci)]
        testX = np.r_[testX,tempX]#.astype(int)
    testsm = SparseModel(testX,cs.Z,C,cs.k)
    qf_mu,qf_cov = testsm.get_qf(cs.mu,cs.scale)
    if cs.mulike is not None:
        qf_mulike,qf_covlike = testsm.get_qf(cs.mulike,cs.scalelike)
        sampslike = testsm.get_samples_one_sensor(cs.mulike,cs.scalelike)
    samps = testsm.get_samples_one_sensor(cs.mu,cs.scale)
    
    plt.figure(figsize=[14,7])
    plt.plot(x,1/(1+qf_mu[:151,0]),'k-')
    
    #plt.plot(x,1/(1+(qf_mu[:151,0]+2*np.sqrt(np.diag(qf_cov)[:151]))+2*np.sqrt(np.exp(qf_mulike[:151,0]))/np.mean(Y[:,0])),'k--',alpha=0.5)
    plt.plot(x,1/(1+(qf_mu[:151,0]-2*np.sqrt(np.diag(qf_cov)[:151]))),'k-',alpha=0.5)
    plt.plot(x,1/(1+(qf_mu[:151,0]+2*np.sqrt(np.diag(qf_cov)[:151]))),'k-',alpha=0.5)

    plt.plot(X[:,0],Y[:,1]/Y[:,0],'x')
    plt.ylim([0,4])
    plt.grid()

# %%
plt.title('standard deviation estimate of likelihood')
plt.plot(x,np.sqrt(np.exp(sampslike[:,:,0].numpy().T)),'b.',alpha=0.1);
plt.gca().set_yscale('log')
#plt.ylim([1e-3,1])

# %%
plt.plot(qf_mulike.numpy())

# %% [markdown]
# ## Linear transform demo
#
# Just two sensors, the low-cost sensor has a drift in which its offset increases over time.
#
# There is obviously some ambiguity from the model's point of view as to whether the difference between the sensors is due scaling or offset.

# %%
X = np.c_[np.linspace(0,20,51),np.zeros(51),np.ones(51)]
y = np.cos(X[:,0])*25+25#+100
Y = np.c_[y,y+X[:,0]+10]
refsensor = np.array([1,0])
Z = np.linspace(0,20,5)[:,None]

# %%
plt.plot(X[:,0],Y[:,0])
plt.plot(X[:,0],Y[:,1])

# %%
#def transform_fn(samps,Y):
#    return 100*(samps[:,:,0:1]) + Y*samps[:,:,1:2] + (samps[:,:,2:3]*Y**2)/1000

def transform_fn(samps,Y,sideY):
    return 10*samps[:,:,0:1] + Y*tf.exp(samps[:,:,1:2])
    #return 100*samps[:,:,0:1] + Y*tf.exp(samps[:,:,1:2])

import tensorflow_probability as tfp
tfd = tfp.distributions
class AltCalibrationSystem(CalibrationSystem):
    def likelihoodfn(self,scaledA,scaledB,ref):
        likelihoodstd = np.sqrt((self.likelihoodstd**2)*np.sum(1-ref,1))
        return tfd.Normal(0,likelihoodstd).log_prob(scaledA-scaledB) #think this is more appropriate for the data

#ks = [gpflow.kernels.RBF(1,15)+gpflow.kernels.Bias(1)]
#kernelindices = [[0]*len(refsensor)]*2
#if we know the lengthscale of the scaling is larger, then we can help the model..
ks = [gpflow.kernels.RBF(1,25)+gpflow.kernels.Bias(1),gpflow.kernels.Bias(0.001**2)]
kernelindices = [[0]*len(refsensor),[1]*len(refsensor)]

cs = AltCalibrationSystem(X, Y, Z, refsensor, 2, transform_fn, ks, kernelindices,likelihoodstd=0.01,lr=0.2)
elbo_record = cs.run(its=50)

# %%
plt.plot(elbo_record)
#plt.ylim([0,300000000])

# %%
#build test matrix
C = 2
for si,refs in enumerate(refsensor):
    if refs: continue
    x = np.linspace(0,15,151)
    testX = np.zeros([0,3])
    for ci in range(C):
        tempX = np.c_[x,np.ones_like(x)*si,np.full_like(x,ci)]
        testX = np.r_[testX,tempX]#.astype(int)
    testsm = SparseModel(testX,cs.Z,C,cs.k)
    qf_mu,qf_cov = testsm.get_qf(cs.mu,cs.scale)
    samps = testsm.get_samples_one_sensor(cs.mu,cs.scale)

    plt.figure(figsize=[6,8])
    plt.subplot(2,1,1)
    plt.plot(x,np.exp(samps[:,:,1].numpy().T),'k.',alpha=0.01);
    plt.hlines(1,0,15,'k',label='scale')
    #plt.plot(-getsensorshift(x,np.ones_like(x).astype(int)))
    plt.grid()
    plt.vlines(Z[:,0],-.3,-.2)
    plt.ylim([0,2])
    plt.xlim([0,15])
    #plt.ylim([0,1.4])
    plt.subplot(2,1,2)
    plt.grid()
    
    plt.plot([0,X[-1,0]],[-10,-X[-1,0]-10],'b-',label='offset')
    plt.plot(x,10*samps[:,:,0].numpy().T,'b.',alpha=0.01);
    plt.legend(loc='lower left')
    #plt.ylim([-20,5])

# %% [markdown]
# # Passing on the calibration

# %%
import numpy as np
from calibration import placeinducingpoints, CalibrationSystem, SparseModel
import gpflow
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = 1.0*np.array([[0,0,1],
              [1,0,2],
              [2,0,1],
              [3,0,2],
              [4,0,1],
              [5,0,2],
              [6,0,1],
              [7,0,2],
              [8,1,3],
              [9,0,2],
             [10,1,3],
             [11,0,2],
             [12,1,3],
             [13,2,4],
             [14,1,3],
             [15,2,4],
             [16,1,3],
             [17,2,4],
             [18,3,5],
             [19,2,4],
             [20,3,5],
             [21,4,5],
             [22,3,5],
             [23,4,5],
             [24,3,5],
             [30,0,5],
             [32,0,5],
             [34,0,5]])
N = len(X)
Y = np.c_[(3.0+X[:,1])*10,(3.0+X[:,2])*10]+np.random.randn(N,2)*0.1
refsensor = np.array([1,0,0,0,0,0])
Z = np.linspace(0,35,7)[:,None]

# %%
np.c_[X,Y]
# Out:
# array([[ 0.        ,  0.        ,  1.        , 30.08031404, 39.88207283],
#        [ 1.        ,  0.        ,  2.        , 30.13825328, 50.08629682],
#        [ 2.        ,  0.        ,  1.        , 30.22532479, 40.02332392],
#        [ 3.        ,  0.        ,  2.        , 30.0328572 , 50.06591191],
#        [ 4.        ,  0.        ,  1.        , 30.13661921, 40.06732146],
#        [ 5.        ,  0.        ,  2.        , 29.84090705, 50.0766268 ],
#        [ 6.        ,  0.        ,  1.        , 29.86257198, 39.99787451],
#        [ 7.        ,  0.        ,  2.        , 29.91100728, 50.1087697 ],
#        [ 8.        ,  1.        ,  3.        , 40.10267752, 60.13666723],
#        [ 9.        ,  0.        ,  2.        , 30.08220348, 49.82645999],
#        [10.        ,  1.        ,  3.        , 39.91589689, 59.90559944],
#        [11.        ,  0.        ,  2.        , 30.04797542, 49.87890459],
#        [12.        ,  1.        ,  3.        , 39.93596613, 60.1312899 ],
#        [13.        ,  2.        ,  4.        , 50.10003472, 70.03616649],
#        [14.        ,  1.        ,  3.        , 40.11527079, 60.13159787],
#        [15.        ,  2.        ,  4.        , 49.98486498, 70.084303  ],
#        [16.        ,  1.        ,  3.        , 39.98543537, 60.14327179],
#        [17.        ,  2.        ,  4.        , 49.96981155, 70.08013745],
#        [18.        ,  3.        ,  5.        , 60.09644497, 79.94642042],
#        [19.        ,  2.        ,  4.        , 49.98807777, 69.90026336],
#        [20.        ,  3.        ,  5.        , 60.05642718, 79.92418694],
#        [21.        ,  4.        ,  5.        , 69.9682318 , 80.05560084],
#        [22.        ,  3.        ,  5.        , 59.77073265, 79.8773301 ],
#        [23.        ,  4.        ,  5.        , 70.00879983, 79.87069462],
#        [24.        ,  3.        ,  5.        , 60.03322971, 79.93562055],
#        [30.        ,  0.        ,  5.        , 30.1094274 , 80.07009031],
#        [32.        ,  0.        ,  5.        , 30.05256639, 79.98935524],
#        [34.        ,  0.        ,  5.        , 30.06696313, 79.95223246]])

# %%
def transform_fn(samps,Y,sideY):
    return Y*tf.exp(samps[:,:,0:1])
k = gpflow.kernels.RBF(1.0,20)+gpflow.kernels.Bias(2.0)
kernelindices = [[0]*len(refsensor)]*1
cs = CalibrationSystem(X, Y, Z, refsensor, 1, transform_fn, [k],kernelindices,likelihoodstd=0.2,lr=0.01)
import time
before = time.time()
elbo_record = cs.run(2000)
print(time.time()-before)
# Out:
# Starting Run
# ....................20 (ELBO=1121698.2500)
# ....................40 (ELBO=679984.1875)
# ....................60 (ELBO=401928.1875)
# ....................80 (ELBO=284972.4375)
# ....................100 (ELBO=217133.3750)
# ....................120 (ELBO=183284.2344)
# ....................140 (ELBO=143723.5938)
# ....................160 (ELBO=126489.5703)
# ....................180 (ELBO=102982.4531)
# ....................200 (ELBO=94360.6484)
# ....................220 (ELBO=80550.9531)
# ....................240 (ELBO=68367.1250)
# ....................260 (ELBO=63898.1250)
# ....................280 (ELBO=56100.2656)
# ....................300 (ELBO=52588.7930)
# ....................320 (ELBO=47951.0625)
# ....................340 (ELBO=43144.2148)
# ....................360 (ELBO=38746.9531)
# ....................380 (ELBO=36789.2266)
# ....................400 (ELBO=33399.1797)
# ....................420 (ELBO=29612.9121)
# ....................440 (ELBO=27484.0117)
# ....................460 (ELBO=26765.2637)
# ....................480 (ELBO=23980.1328)
# ....................500 (ELBO=22323.5195)
# ....................520 (ELBO=20126.1094)
# ....................540 (ELBO=18407.2090)
# ....................560 (ELBO=16896.9707)
# ....................580 (ELBO=16365.7988)
# ....................600 (ELBO=14622.9785)
# ....................620 (ELBO=13587.4658)
# ....................640 (ELBO=12910.0166)
# ....................660 (ELBO=12679.7539)
# ....................680 (ELBO=10894.7773)
# ....................700 (ELBO=10871.4609)
# ....................720 (ELBO=9649.6680)
# ....................740 (ELBO=8821.4492)
# ....................760 (ELBO=8304.7227)
# ....................780 (ELBO=8293.3447)
# ....................800 (ELBO=7283.9585)
# ....................820 (ELBO=6996.8560)
# ....................840 (ELBO=6490.8027)
# ....................860 (ELBO=5836.4224)
# ....................880 (ELBO=5633.5581)
# ....................900 (ELBO=5239.0132)
# ....................920 (ELBO=4648.4507)
# ....................940 (ELBO=4501.4287)
# ....................960 (ELBO=4250.5669)
# ....................980 (ELBO=4131.3428)
# ....................1000 (ELBO=3837.5244)
# ....................1020 (ELBO=3576.2573)
# ....................1040 (ELBO=3368.3643)
# ....................1060 (ELBO=3288.7651)
# ....................1080 (ELBO=3127.1543)
# ....................1100 (ELBO=2817.8188)
# ....................1120 (ELBO=2710.4023)
# ....................1140 (ELBO=2612.6855)
# ....................1160 (ELBO=2440.3110)
# ....................1180 (ELBO=2287.2119)
# ....................1200 (ELBO=2226.1196)
# ....................1220 (ELBO=2104.1692)
# ....................1240 (ELBO=1967.5074)
# ....................1260 (ELBO=1918.4031)
# ....................1280 (ELBO=1711.2205)
# ....................1300 (ELBO=1747.0740)
# ....................1320 (ELBO=1650.2465)
# ....................1340 (ELBO=1572.8868)
# ....................1360 (ELBO=1514.7524)
# ....................1380 (ELBO=1492.2437)
# ....................1400 (ELBO=1394.1926)
# ....................1420 (ELBO=1316.3540)
# ....................1440 (ELBO=1310.1545)
# ....................1460 (ELBO=1215.3396)
# ....................1480 (ELBO=1251.9668)
# ....................1500 (ELBO=1146.9702)
# ....................1520 (ELBO=1125.7756)
# ....................1540 (ELBO=1107.3925)
# ....................1560 (ELBO=1000.9290)
# ....................1580 (ELBO=1014.8172)
# ....................1600 (ELBO=964.5149)
# ....................1620 (ELBO=901.3923)
# ....................1640 (ELBO=915.7822)
# ....................1660 (ELBO=868.9082)
# ....................1680 (ELBO=850.4183)
# ....................1700 (ELBO=857.5592)
# ....................1720 (ELBO=840.7513)
# ....................1740 (ELBO=827.0458)
# ....................1760 (ELBO=808.6306)
# ....................1780 (ELBO=778.6948)
# ....................1800 (ELBO=755.4993)
# ....................1820 (ELBO=746.1613)
# ....................1840 (ELBO=724.9476)
# ....................1860 (ELBO=687.6229)
# ....................1880 (ELBO=703.2051)
# ....................1900 (ELBO=681.7515)
# ....................1920 (ELBO=675.6359)
# ....................1940 (ELBO=685.8439)
# ....................1960 (ELBO=641.7202)
# ....................1980 (ELBO=626.9738)
# ....................2000 (ELBO=617.6150)
# 179.54189538955688

# %%
C = 1
Ttotal = 35
for si,refs in enumerate(refsensor):
    if refs: continue
    x = np.linspace(0,Ttotal,100)
    testX = np.zeros([0,3])
    for ci in range(C):
        tempX = np.c_[x,np.ones_like(x)*si,np.full_like(x,ci)]
        testX = np.r_[testX,tempX]#.astype(int)
    testsm = SparseModel(testX,cs.Z,C,cs.k)
    qf_mu,qf_cov = testsm.get_qf(cs.mu,cs.scale)
    if cs.mulike is not None:
        qf_mulike,qf_covlike = testsm.get_qf(cs.mulike,cs.scalelike)
        sampslike = testsm.get_samples_one_sensor(cs.mulike,cs.scalelike)
    samps = testsm.get_samples_one_sensor(cs.mu,cs.scale)
    
    plt.figure(figsize=[7,3.5])
    #plt.plot(x,1/(1+qf_mu[:,0]),'k-')
    plt.plot(x,1/tf.exp(qf_mu[:,0]),'k-')
    #plt.plot(x,1/(1+qf_mu[:151,0])+2*np.sqrt(np.diag(qf_cov)[:151])+2*np.sqrt(np.exp(qf_mulike[:151,0]))/np.mean(Y[:,0]),'k--',alpha=0.5)
    #plt.plot(x,1/(1+qf_mu[:151,0])-2*np.sqrt(np.diag(qf_cov)[:151])-2*np.sqrt(np.exp(qf_mulike[:151,0]))/np.mean(Y[:,0]),'k--',alpha=0.5)
    #plt.plot(x,1/(1+(qf_mu[:151,0]+2*np.sqrt(np.diag(qf_cov)[:151]))+2*np.sqrt(np.exp(qf_mulike[:151,0]))/np.mean(Y[:,0])),'k--',alpha=0.5)
    #r = (1/(1+(qf_mu[:,0]-2*np.sqrt(np.diag(qf_cov)[:])))).numpy()
    #r[r<0] = np.nan
    #plt.plot(x,r,'k-',alpha=0.5)
    #plt.plot(x,1/(1+(qf_mu[:,0]+2*np.sqrt(np.diag(qf_cov)[:]))),'k-',alpha=0.5)
    plt.plot(x,1/tf.exp((qf_mu[:,0]+2*np.sqrt(np.diag(qf_cov)[:]))),'k-',alpha=0.5)
    plt.plot(x,1/tf.exp((qf_mu[:,0]-2*np.sqrt(np.diag(qf_cov)[:]))),'k-',alpha=0.5)
    
    senseX = (X[:,1]==si)
    plt.plot(X[senseX,0],Y[senseX,0]/Y[senseX,1],'xg')
    for x,y in zip(X[senseX,:],Y[senseX,:]):
        plt.text(x[0],y[0]/y[1],"%d" % x[2])
    senseX = (X[:,2]==si)
    plt.plot(X[senseX,0],Y[senseX,1]/Y[senseX,0],'xg')
    for x,y in zip(X[senseX,:],Y[senseX,:]):
        plt.text(x[0],y[1]/y[0],"%d" % x[1])
    plt.hlines((3.0+si)/3.0,0,35,'b')
    plt.ylim([0,4])
    #plt.ylim([0.5,10])
    #plt.yscale('log')
    plt.grid()
    plt.title("Sensor %d"  % si)
